# %%
import pandas as pd

# %%
df =  pd.read_csv('https://raw.githubusercontent.com/DataTalksClub/machine-learning-zoomcamp/main/cohorts/2026/data/car_fuel_efficiency_2026.csv')

# %%
df
# Out:
#       model_year  origin fuel_type         drivetrain  num_doors  \
# 0           2006  Europe  Gasoline  Front-wheel drive          4
# 1           2008  Europe    Diesel  Front-wheel drive          4
# 2           1996    Asia  Gasoline  Front-wheel drive          5
# 3           1989  Europe  Gasoline  Front-wheel drive          4
# 4           1994     USA    Diesel  Front-wheel drive          3
# ...          ...     ...       ...                ...        ...
# 9995        2005     USA  Gasoline    All-wheel drive          4
# 9996        1993    Asia  Gasoline    All-wheel drive          2
# 9997        2014     USA  Gasoline    All-wheel drive          3
# 9998        2004     USA    Hybrid   Rear-wheel drive          5
# 9999        2011     USA    Diesel  Front-wheel drive          4
#
#       engine_displacement  num_cylinders  horsepower  vehicle_weight  \
# 0                    2180              6       243.0            3870
# ...

# %%
df.head()
# Out:
#    model_year  origin fuel_type         drivetrain  num_doors  \
# 0        2006  Europe  Gasoline  Front-wheel drive          4
# 1        2008  Europe    Diesel  Front-wheel drive          4
# 2        1996    Asia  Gasoline  Front-wheel drive          5
# 3        1989  Europe  Gasoline  Front-wheel drive          4
# 4        1994     USA    Diesel  Front-wheel drive          3
#
#    engine_displacement  num_cylinders  horsepower  vehicle_weight  \
# 0                 2180              6       243.0            3870
# 1                 2390              6       272.0            4210
# 2                 2320              6       267.0            4240
# 3                 2130              6       258.0            4490
# 4                 2580              7       304.0            4510
#
#    acceleration  fuel_efficiency_mpg
# 0           NaN                 31.9
# 1           NaN                 31.3
# 2          17.3                 27.5
# 3          18.7                 28.5
# ...

# %%
df.fuel_type.nunique()
# Out:
# 3

# %%
df.isnull().sum()
# Out:
# model_year               0
# origin                   0
# fuel_type                0
# drivetrain               0
# num_doors                0
# engine_displacement      0
# num_cylinders            0
# horsepower             877
# vehicle_weight           0
# acceleration           264
# fuel_efficiency_mpg      0
# dtype: int64

# %%
df.groupby('origin').fuel_efficiency_mpg.max()
# Out:
# origin
# Asia      41.2
# Europe    39.4
# USA       38.2
# Name: fuel_efficiency_mpg, dtype: float64

# %%
df.horsepower.describe()
# Out:
# count    9123.000000
# mean      254.446016
# std        22.844613
# min       171.000000
# 25%       239.000000
# 50%       254.000000
# 75%       270.000000
# max       334.000000
# Name: horsepower, dtype: float64

# %%
df['horsepower'].median()
# Out:
# np.float64(254.0)

# %%
df.horsepower.value_count()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 df.horsepower.value_count()
#
# File /usr/local/python/3.14.2/lib/python3.14/site-packages/pandas/core/generic.py:6194, in NDFrame.__getattr__(self, name)
#    6190             and name not in self._accessors
#    6191             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6192         ):
#    6193             return self[name]
# -> 6194         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'value_count'

# %%
df.horsepower.value_counts()
# Out:
# horsepower
# 252.0    174
# 246.0    168
# 256.0    168
# 259.0    165
# 253.0    165
#         ...
# 322.0      1
# 330.0      1
# 175.0      1
# 178.0      1
# 320.0      1
# Name: count, Length: 153, dtype: int64

# %%
df.horsepower.mode()[0]
# Out:
# np.float64(252.0)

# %%
df.fillna(252.0, inplace=True)
# Out:
#       model_year  origin fuel_type         drivetrain  num_doors  \
# 0           2006  Europe  Gasoline  Front-wheel drive          4
# 1           2008  Europe    Diesel  Front-wheel drive          4
# 2           1996    Asia  Gasoline  Front-wheel drive          5
# 3           1989  Europe  Gasoline  Front-wheel drive          4
# 4           1994     USA    Diesel  Front-wheel drive          3
# ...          ...     ...       ...                ...        ...
# 9995        2005     USA  Gasoline    All-wheel drive          4
# 9996        1993    Asia  Gasoline    All-wheel drive          2
# 9997        2014     USA  Gasoline    All-wheel drive          3
# 9998        2004     USA    Hybrid   Rear-wheel drive          5
# 9999        2011     USA    Diesel  Front-wheel drive          4
#
#       engine_displacement  num_cylinders  horsepower  vehicle_weight  \
# 0                    2180              6       243.0            3870
# ...

# %%
df.horsepower.isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9995    False
# 9996    False
# 9997    False
# 9998    False
# 9999    False
# Name: horsepower, Length: 10000, dtype: bool

# %%
df.horsepower.isnull().sum()
# Out:
# np.int64(0)

# %%
df['horsepower'].median()
# Out:
# np.float64(252.0)

# %%
df.groupby('origin' == 'Asia').[['vehicle_weight', 'model_year']].head(7).values
# Out:
#   Cell In[18], line 1
#     df.groupby('origin' == 'Asia').[['vehicle_weight', 'model_year']].head(7).values
#                                    ^
# SyntaxError: invalid syntax

# %%
df.groupby('origin' == 'Asia').['vehicle_weight', 'model_year'].head(7).values
# Out:
#   Cell In[19], line 1
#     df.groupby('origin' == 'Asia').['vehicle_weight', 'model_year'].head(7).values
#                                    ^
# SyntaxError: invalid syntax

# %%
df.groupby('origin' == 'Asia').vehicle_weight.model_year.head(7).values
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 df.groupby('origin' == 'Asia').vehicle_weight.model_year.head(7).values
#
# File /usr/local/python/3.14.2/lib/python3.14/site-packages/pandas/util/_decorators.py:336, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     330 if len(args) > num_allow_args:
#     331     warnings.warn(
#     332         msg.format(arguments=_format_argument_list(allow_args)),
#     333         klass,
#     334         stacklevel=find_stack_level(),
#     335     )
# --> 336 return func(*args, **kwargs)
#
# File /usr/local/python/3.14.2/lib/python3.14/site-packages/pandas/core/frame.py:10835, in DataFrame.groupby(self, by, level, as_index, sort, group_keys, observed, dropna)
#   10831
#   10832         if level is None and by is None:
# ...

# %%
df.groupby('origin' == 'Asia').vehicle_weight.model_year.head(7)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 df.groupby('origin' == 'Asia').vehicle_weight.model_year.head(7)
#
# File /usr/local/python/3.14.2/lib/python3.14/site-packages/pandas/util/_decorators.py:336, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     330 if len(args) > num_allow_args:
#     331     warnings.warn(
#     332         msg.format(arguments=_format_argument_list(allow_args)),
#     333         klass,
#     334         stacklevel=find_stack_level(),
#     335     )
# --> 336 return func(*args, **kwargs)
#
# File /usr/local/python/3.14.2/lib/python3.14/site-packages/pandas/core/frame.py:10835, in DataFrame.groupby(self, by, level, as_index, sort, group_keys, observed, dropna)
#   10831
#   10832         if level is None and by is None:
# ...

# %%
df
# Out:
#       model_year  origin fuel_type         drivetrain  num_doors  \
# 0           2006  Europe  Gasoline  Front-wheel drive          4
# 1           2008  Europe    Diesel  Front-wheel drive          4
# 2           1996    Asia  Gasoline  Front-wheel drive          5
# 3           1989  Europe  Gasoline  Front-wheel drive          4
# 4           1994     USA    Diesel  Front-wheel drive          3
# ...          ...     ...       ...                ...        ...
# 9995        2005     USA  Gasoline    All-wheel drive          4
# 9996        1993    Asia  Gasoline    All-wheel drive          2
# 9997        2014     USA  Gasoline    All-wheel drive          3
# 9998        2004     USA    Hybrid   Rear-wheel drive          5
# 9999        2011     USA    Diesel  Front-wheel drive          4
#
#       engine_displacement  num_cylinders  horsepower  vehicle_weight  \
# 0                    2180              6       243.0            3870
# ...

# %%
df.groupby('origin').get_group('Asia')[['vehicle_weight', 'model_year']].head(7)
# Out:
#     vehicle_weight  model_year
# 2             4240        1996
# 6             4310        1992
# 8             4230        1997
# 10            4420        1978
# 15            3950        2007
# 16            4750        2021
# 22            4450        2019

# %%
np_array = df.groupby('origin').get_group('Asia')[['vehicle_weight', 'model_year']].head(7)

# %%
np_array.values()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 np_array.values()
#
# TypeError: 'numpy.ndarray' object is not callable

# %%
X = np_array.values

# %%
X
# Out:
# array([[4240, 1996],
#        [4310, 1992],
#        [4230, 1997],
#        [4420, 1978],
#        [3950, 2007],
#        [4750, 2021],
#        [4450, 2019]])

# %%
XT = X.T
XT
# Out:
# array([[4240, 4310, 4230, 4420, 3950, 4750, 4450],
#        [1996, 1992, 1997, 1978, 2007, 2021, 2019]])

# %%
XTX = XT.dot(X)

# %%
XTX
# Out:
# array([[131950500,  60750580],
#        [ 60750580,  28041424]])

# %%
XTX_inv = np.linalg.inv(XTX)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 XTX_inv = np.linalg.inv(XTX)
#
# NameError: name 'np' is not defined

# %%
import numpy as np

# %%
XTX_inv = np.linalg.inv(XTX)
XTX_inv
# Out:
# array([[ 2.96830537e-06, -6.43071025e-06],
#        [-6.43071025e-06,  1.39675281e-05]])

# %%
y = np.array([1100, 1300, 800, 900, 1000, 1100, 1200])

# %%
y
# Out:
# array([1100, 1300,  800,  900, 1000, 1100, 1200])

# %%
w = (np.linalg.inv(XTX) * X.T) * y
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 w = (np.linalg.inv(XTX) * X.T) * y
#
# ValueError: operands could not be broadcast together with shapes (2,2) (2,7)

# %%
XTX_inv_XT = XTX_inv.dot(XT)

# %%
w = XTX_inv_XT.dot(y)
w
# Out:
# array([0.13644777, 0.2327492 ])

# %%
result = w[0] + w[1]

# %%
result
# Out:
# np.float64(0.36919696904925486)
